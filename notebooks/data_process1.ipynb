# %% [markdown]
# ### 数据A

# %%
#读取CSV文件
import numpy as np
import pandas as pd
import random

data_A_class=pd.read_csv('html_data/A-Class_articles.csv',header=None)
data_A_class=data_A_class.drop(data_A_class.index[-1])
data_A_class.columns=['html']
data_A_class

# %%
data_A_class=data_A_class[data_A_class['html'].str.contains('Talk')]
data_A_class

# %%
data_A_class=pd.DataFrame(data_A_class)
data_A_class=data_A_class.drop_duplicates()
data_A_class=data_A_class.reset_index(drop=True)
data_A_class

# %% [markdown]
# ### 数据B

# %%
data_B_class=pd.read_csv('html_data/B-Class_articles.csv',header=None)
data_B_class=data_B_class.drop(data_B_class.index[-1])
data_B_class.columns=['html']
data_B_class

# %%
data_B_class=data_B_class[data_B_class['html'].str.contains('Talk')]
data_B_class=pd.DataFrame(data_B_class)
data_B_class=data_B_class.drop_duplicates()
data_B_class=data_B_class.reset_index(drop=True)
data_B_class

# %% [markdown]
# ### 数据C

# %%
data_C_class1=pd.read_csv('html_data/C-Class_articles1.csv',header=None)
data_C_class1=data_C_class1.drop(data_C_class1.index[-1])
data_C_class1.columns=['html']
data_C_class1

# %%
data_C_class1=data_C_class1[data_C_class1['html'].str.contains('Talk')]
data_C_class1

# %%
data_C_class1=pd.DataFrame(data_C_class1)
data_C_class1=data_C_class1.drop_duplicates()
data_C_class1=data_C_class1.reset_index(drop=True)
data_C_class1

# %%
data_C_class2=pd.read_csv('html_data/C-Class_articles2.csv',header=None)
data_C_class2=data_C_class2.drop(data_C_class2.index[-1])
data_C_class2.columns=['html']
data_C_class2

# %%
data_C_class2=data_C_class2[data_C_class2['html'].str.contains('Talk')]
data_C_class2=pd.DataFrame(data_C_class2)
data_C_class2=data_C_class2.drop_duplicates()
data_C_class2=data_C_class2.reset_index(drop=True)
data_C_class2

# %%
temp_data=pd.concat([data_C_class1,data_C_class2])
temp_data=temp_data.drop_duplicates()
temp_data=temp_data.reset_index(drop=True)
temp_data

# %%
data_C_class3=pd.read_csv('html_data/C-Class_articles3.csv',header=None)
data_C_class3=data_C_class3.drop(data_C_class3.index[-1])
data_C_class3.columns=['html']
data_C_class3

# %%
data_C_class3=data_C_class3[data_C_class3['html'].str.contains('Talk')]
data_C_class3=pd.DataFrame(data_C_class3)
data_C_class3=data_C_class3.drop_duplicates()
data_C_class3=data_C_class3.reset_index(drop=True)
data_C_class3

# %%
data_C_class=pd.concat([temp_data,data_C_class3])
data_C_class=data_C_class.drop_duplicates()
data_C_class=data_C_class.reset_index(drop=True)
data_C_class

# %% [markdown]
# ### 数据FA

# %%
data_FA_class=pd.read_csv('html_data/FA-Class_articles.csv',header=None)
data_FA_class=data_FA_class.drop(data_FA_class.index[-1])
data_FA_class.columns=['html']
data_FA_class

# %%
data_FA_class=data_FA_class[data_FA_class['html'].str.contains('Talk')]
data_FA_class=pd.DataFrame(data_FA_class)
data_FA_class=data_FA_class.drop_duplicates()
data_FA_class=data_FA_class.reset_index(drop=True)
data_FA_class

# %% [markdown]
# ### 数据FL

# %%
data_FL_class=pd.read_csv('html_data/FL-Class_articles.csv',header=None)
data_FL_class=data_FL_class.drop(data_FL_class.index[-1])
data_FL_class.columns=['html']
data_FL_class

# %%
data_FL_class=data_FL_class[data_FL_class['html'].str.contains('Talk')]
data_FL_class=pd.DataFrame(data_FL_class)
data_FL_class=data_FL_class.drop_duplicates()
data_FL_class=data_FL_class.reset_index(drop=True)
data_FL_class

# %% [markdown]
# ### 数据GA

# %%
data_GA_class=pd.read_csv('html_data/GA-Class_articles.csv',header=None)
data_GA_class=data_GA_class.drop(data_GA_class.index[-1])
data_GA_class.columns=['html']
data_GA_class

# %%
data_GA_class=data_GA_class[data_GA_class['html'].str.contains('Talk')]
data_GA_class=pd.DataFrame(data_GA_class)
data_GA_class=data_GA_class.drop_duplicates()
data_GA_class=data_GA_class.reset_index(drop=True)
data_GA_class

# %% [markdown]
# ### 数据List

# %%
data_List_class=pd.read_csv('html_data/List-Class_articles.csv',header=None)
data_List_class=data_List_class.drop(data_List_class.index[-1])
data_List_class.columns=['html']
data_List_class

# %%
data_List_class=data_List_class[data_List_class['html'].str.contains('Talk')]
data_List_class=pd.DataFrame(data_List_class)
data_List_class=data_List_class.drop_duplicates()
data_List_class=data_List_class.reset_index(drop=True)
data_List_class

# %% [markdown]
# ###  数据Start

# %%
data_Start_class1=pd.read_csv('html_data/Start-Class_articles1.csv',header=None)
data_Start_class1=data_Start_class1.drop(data_Start_class1.index[-1])
data_Start_class1.columns=['html']

data_Start_class2=pd.read_csv('html_data/Start-Class_articles2.csv',header=None)
data_Start_class2=data_Start_class2.drop(data_Start_class2.index[-1])
data_Start_class2.columns=['html']

data_Start_class3=pd.read_csv('html_data/Start-Class_articles3.csv',header=None)
data_Start_class3=data_Start_class3.drop(data_Start_class3.index[-1])
data_Start_class3.columns=['html']

data_Start_class4=pd.read_csv('html_data/Start-Class_articles4.csv',header=None)
data_Start_class4=data_Start_class4.drop(data_Start_class4.index[-1])
data_Start_class4.columns=['html']

data_Start_class5=pd.read_csv('html_data/Start-Class_articles5.csv',header=None)
data_Start_class5=data_Start_class5.drop(data_Start_class5.index[-1])
data_Start_class5.columns=['html']

data_Start_class6=pd.read_csv('html_data/Start-Class_articles6.csv',header=None)
data_Start_class6=data_Start_class6.drop(data_Start_class6.index[-1])
data_Start_class6.columns=['html']

data_Start_class7=pd.read_csv('html_data/Start-Class_articles7.csv',header=None)
data_Start_class7=data_Start_class7.drop(data_Start_class7.index[-1])
data_Start_class7.columns=['html']

# %%
data_Start_class1=data_Start_class1[data_Start_class1['html'].str.contains('Talk')]
data_Start_class1=pd.DataFrame(data_Start_class1)
data_Start_class1=data_Start_class1.drop_duplicates()
data_Start_class1=data_Start_class1.reset_index(drop=True)

data_Start_class2=data_Start_class2[data_Start_class2['html'].str.contains('Talk')]
data_Start_class2=pd.DataFrame(data_Start_class2)
data_Start_class2=data_Start_class2.drop_duplicates()
data_Start_class2=data_Start_class2.reset_index(drop=True)

data_Start_class3=data_Start_class3[data_Start_class3['html'].str.contains('Talk')]
data_Start_class3=pd.DataFrame(data_Start_class3)
data_Start_class3=data_Start_class3.drop_duplicates()
data_Start_class3=data_Start_class3.reset_index(drop=True)

data_Start_class4=data_Start_class4[data_Start_class4['html'].str.contains('Talk')]
data_Start_class4=pd.DataFrame(data_Start_class4)
data_Start_class4=data_Start_class4.drop_duplicates()
data_Start_class4=data_Start_class4.reset_index(drop=True)

data_Start_class5=data_Start_class5[data_Start_class5['html'].str.contains('Talk')]
data_Start_class5=pd.DataFrame(data_Start_class5)
data_Start_class5=data_Start_class5.drop_duplicates()
data_Start_class5=data_Start_class5.reset_index(drop=True)

data_Start_class6=data_Start_class6[data_Start_class6['html'].str.contains('Talk')]
data_Start_class6=pd.DataFrame(data_Start_class6)
data_Start_class6=data_Start_class6.drop_duplicates()
data_Start_class6=data_Start_class6.reset_index(drop=True)

data_Start_class7=data_Start_class7[data_Start_class7['html'].str.contains('Talk')]
data_Start_class7=pd.DataFrame(data_Start_class7)
data_Start_class7=data_Start_class7.drop_duplicates()
data_Start_class7=data_Start_class7.reset_index(drop=True)

# %%
data_Start_class=pd.concat([data_Start_class1,data_Start_class2,data_Start_class3,data_Start_class4,data_Start_class5,data_Start_class6,data_Start_class7])
data_Start_class=data_Start_class.drop_duplicates()
data_Start_class=data_Start_class.reset_index(drop=True)
data_Start_class

# %% [markdown]
# ###  数据Stub

# %%
data_Stub_class1=pd.read_csv('html_data/Stub-Class_articles1.csv',header=None)
data_Stub_class1=data_Stub_class1.drop(data_Stub_class1.index[-1])
data_Stub_class1.columns=['html']

data_Stub_class2=pd.read_csv('html_data/Stub-Class_articles2.csv',header=None)
data_Stub_class2=data_Stub_class2.drop(data_Stub_class2.index[-1])
data_Stub_class2.columns=['html']

data_Stub_class3=pd.read_csv('html_data/Stub-Class_articles3.csv',header=None)
data_Stub_class3=data_Stub_class3.drop(data_Stub_class3.index[-1])
data_Stub_class3.columns=['html']

data_Stub_class4=pd.read_csv('html_data/Stub-Class_articles4.csv',header=None)
data_Stub_class4=data_Stub_class4.drop(data_Stub_class4.index[-1])
data_Stub_class4.columns=['html']

data_Stub_class5=pd.read_csv('html_data/Stub-Class_articles5.csv',header=None)
data_Stub_class5=data_Stub_class5.drop(data_Stub_class5.index[-1])
data_Stub_class5.columns=['html']

data_Stub_class6=pd.read_csv('html_data/Stub-Class_articles6.csv',header=None)
data_Stub_class6=data_Stub_class6.drop(data_Stub_class6.index[-1])
data_Stub_class6.columns=['html']

data_Stub_class7=pd.read_csv('html_data/Stub-Class_articles7.csv',header=None)
data_Stub_class7=data_Stub_class7.drop(data_Stub_class7.index[-1])
data_Stub_class7.columns=['html']

data_Stub_class8=pd.read_csv('html_data/Stub-Class_articles8.csv',header=None)
data_Stub_class8=data_Stub_class8.drop(data_Stub_class8.index[-1])
data_Stub_class8.columns=['html']

# %%
data_Stub_class1=data_Stub_class1[data_Stub_class1['html'].str.contains('Talk')]
data_Stub_class1=pd.DataFrame(data_Stub_class1)
data_Stub_class1=data_Stub_class1.drop_duplicates()
data_Stub_class1=data_Stub_class1.reset_index(drop=True)

data_Stub_class2=data_Stub_class2[data_Stub_class2['html'].str.contains('Talk')]
data_Stub_class2=pd.DataFrame(data_Stub_class2)
data_Stub_class2=data_Stub_class2.drop_duplicates()
data_Stub_class2=data_Stub_class2.reset_index(drop=True)

data_Stub_class3=data_Stub_class3[data_Stub_class3['html'].str.contains('Talk')]
data_Stub_class3=pd.DataFrame(data_Stub_class3)
data_Stub_class3=data_Stub_class3.drop_duplicates()
data_Stub_class3=data_Stub_class3.reset_index(drop=True)

data_Stub_class4=data_Stub_class4[data_Stub_class4['html'].str.contains('Talk')]
data_Stub_class4=pd.DataFrame(data_Stub_class4)
data_Stub_class4=data_Stub_class4.drop_duplicates()
data_Stub_class4=data_Stub_class4.reset_index(drop=True)

data_Stub_class5=data_Stub_class5[data_Stub_class5['html'].str.contains('Talk')]
data_Stub_class5=pd.DataFrame(data_Stub_class5)
data_Stub_class5=data_Stub_class5.drop_duplicates()
data_Stub_class5=data_Stub_class5.reset_index(drop=True)

data_Stub_class6=data_Stub_class6[data_Stub_class6['html'].str.contains('Talk')]
data_Stub_class6=pd.DataFrame(data_Stub_class6)
data_Stub_class6=data_Stub_class6.drop_duplicates()
data_Stub_class6=data_Stub_class6.reset_index(drop=True)

data_Stub_class7=data_Stub_class7[data_Stub_class7['html'].str.contains('Talk')]
data_Stub_class7=pd.DataFrame(data_Stub_class7)
data_Stub_class7=data_Stub_class7.drop_duplicates()
data_Stub_class7=data_Stub_class7.reset_index(drop=True)

data_Stub_class8=data_Stub_class8[data_Stub_class8['html'].str.contains('Talk')]
data_Stub_class8=pd.DataFrame(data_Stub_class8)
data_Stub_class8=data_Stub_class8.drop_duplicates()
data_Stub_class8=data_Stub_class8.reset_index(drop=True)

# %%
data_Stub_class=pd.concat([data_Stub_class1,data_Stub_class2,data_Stub_class3,data_Stub_class4,data_Stub_class5,data_Stub_class6,data_Stub_class7,data_Stub_class8])
data_Stub_class=data_Stub_class.drop_duplicates()
data_Stub_class=data_Stub_class.reset_index(drop=True)
data_Stub_class

# %% [markdown]
# ### 样本总量

# %%
sum_len=(len(data_A_class)+len(data_B_class)+len(data_C_class)+len(data_FA_class)+len(data_FL_class)+len(data_GA_class)+len(data_List_class)+len(data_Start_class)+len(data_Stub_class))
print(sum_len)

# %%
data=pd.concat([data_A_class,data_B_class,data_C_class,data_FA_class,data_FL_class,data_GA_class,data_List_class,data_Start_class,data_Stub_class])

# %%
temp_df=data
label_data=['A']*len(data_A_class)+['B']*len(data_B_class)+['C']*len(data_C_class)+['FA']*len(data_FA_class)+['FL']*len(data_FL_class)+['GA']*len(data_GA_class)+['List']*len(data_List_class)+['Start']*len(data_Start_class)+['Stub']*len(data_Stub_class)

# %%
data=list(data['html'])

# %%
# 合并为DataFrame
df = pd.DataFrame({'Column1':data, 'Column2':label_data})
df.columns=['html','label']
df

# %% [markdown]
# ### 空值查询

# %%
df.info()

# %% [markdown]
# ### 重复值查询

# %%
df['html'].value_counts()

# %%
df=df.drop_duplicates(subset=['html'], inplace=False,ignore_index=True)
df

# %% [markdown]
# 数据中存在重复值，经过重新查验后发现，重复值为Wikipedia网站（英语版）分类不清晰的问题，因此此处将重复网址去掉，只保存唯一

# %%
df['label'].value_counts()

# %%
data_A_class=df[df['label']=='A']
data_A_class.to_csv('new_A-Class_articles.csv',header=None,index=None)

# %%
data_FA_class=df[df['label']=='FA']
data_FA_class.to_csv('new_FA-Class_articles.csv',header=None,index=None)

# %%
data_FL_class=df[df['label']=='FL']
data_FL_class.to_csv('new_FL-Class_articles.csv',header=None,index=None)

# %%
df['html'] = df['html'].str.replace('Talk:', '')
df

# %%
df.to_csv('new_articles_sumtype.csv',header=None,index=None)

# %% [markdown]
# ### 主题1000类型判断

# %%
sum_type=pd.read_csv('D:/Biyesheji1/网页随机抽样1000.csv',header=None)
sum_type.columns=['html']
sum_type

# %%
merged_df=pd.merge(sum_type,df,on='html', how='left')
merged_df

# %%
merged_df['label'].value_counts()

# %%
temp_list=['People']*114+['History']*84+['Geography']*106+['Arts']*45+['Philosophy and religion']*55+['Everyday life']*57+['Society and social sciences']*146+['Health, medicine and disease']*41+['Science']*212+['Technology']*97+['Mathematics']*45
temp_list

# %%
merged_df.insert(2,'type',temp_list)
merged_df

# %%
merged_df.to_csv('D:/Biyesheji1/网页随机抽样1000类型.csv',header=None,index=None)

# %% [markdown]
# ### 分层抽样

# %%
from sklearn.model_selection import train_test_split

def stratify_sample(array, label, size):
    """分层抽样: 先按照容量，给每个样本一些指标，然后样本内等概率抽样
    :param array: 样本数据
    :param label: 样本类别
    :param size: 采样个数
    """
    stratified_sample, _ = train_test_split(array, train_size=size, stratify=label)
    return stratified_sample

# %%
import warnings
warnings.filterwarnings("ignore",category=DeprecationWarning)

# %%
sample=stratify_sample(np.array(data),np.array(label_data),10000)

# %%
df_sample=pd.DataFrame(sample)
df_sample.columns=['html']
df_sample

# %%
new_data=pd.merge(df_sample,df,on='html', how='left')
new_data

# %%
len(list(set(new_data['html'])))

# %%
import pandas as pd

# 示例 DataFrame
left_df = pd.DataFrame({'key': ['K0', 'K1', 'K2', 'K3'],
                        'value_left': [1, 2, 3, 4]})

right_df = pd.DataFrame({'key': ['K1', 'K2', 'K3', 'K4'],
                         'value_right': [5, 6, 7, 8]})

# 按照 'key' 列的值以左边数据集为准合并两个 DataFrame
result = pd.merge(left_df, right_df, on='key', how='left')

print("按照 'key' 列合并以左边数据集为准的结果：")
print(result)

# %%
from collections import Counter

# 使用Counter计数
counter = Counter(sample)

# 打印各类别数量
for category, count in counter.items():
    print(f'类别 {category} 出现 {count} 次')

# %%
data_len=10000
rate=[]
for i in data:
    rate.append(float("{:.5f}".format(len(i)/sum_len)))
    
print(rate)
print(sum(rate))

# %%
data_fenceng=[(data_len * i) for i in rate]
print(sum(data_fenceng))
print(data_fenceng)

# %%
new_data=[[]]*5
print(new_data)

# %%
new_data=[[]]*len(data_fenceng)
for i in range(len(data_fenceng)):
    new_data[i]=random.sample(data[i], int(data_fenceng[i]))

new_data

# %%
for i in new_data:
    print(len(i))

# %%
new_data=(pd.DataFrame(new_data).T)
new_data.columns=['data_A_class','data_B_class','data_C_class','data_FA_class','data_FL_class','data_GA_class','data_List_class','data_Start_class','data_Stub_class']

new_data.to_csv('10000fenceng_data.csv',header=True, index=False)

# %%
new_data=pd.read_csv('10000fenceng_data.csv')
new_data

# %%
for i in ['data_A_class','data_B_class','data_C_class','data_FA_class','data_FL_class','data_GA_class','data_List_class','data_Start_class','data_Stub_class']:
    temp_list=list(new_data['data_A_class'].dropna())
    print(temp_list)
